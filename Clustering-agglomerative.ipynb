# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import MeanShift
sns.set()
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
data=pd.read_csv(r'E:\ML\Sofia-\PPL.csv')

# %%
data
# Out:
#     CA100  FT100
# 0      61     53
# 1      67     48
# 2      74     73
# 3      87     90
# 4      69     50
# 5      63     53
# 6      71     80
# 7      81     98
# 8      68     48
# 9      66     38
# 10     63     65
# 11     67     52
# 12     74     58
# 13     63     62
# 14     61     57
# 15     64     65
# 16     77     47
# 17     68     48
# 18     68     55
# 19     74     32
# 20     83     58
# 21     72     63
# 22     70     53
# 23     68     63
# 24     87     78
# 25     54     47
# 26     63     43
# 27     67     67
# 28     72     60
# 29     60     47
# 30     73     53
# 31     58     42
# 32     64     48
# 33     67     52
# 34     68     57
# 35     77     48
# 36     77     77
# 37     76     68
# 38     69     58
# 39     80     70
# 40     80     82
# 41     62     63
# 42     76     70
# 43     64     38
# 44     81     67
# 45     73     73
# 46     77     75
# 47     68     50
# 48     69     57
# 49     73     60

# %%
plt.scatter(data['CA100'],data['FT100'])
plt.xlabel('Continuous Assessment')
plt.ylabel('Formative Test')
plt.show()

# %%
x=data.copy()

# %%
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(x)

# %%
clusters=x.copy()
clusters['cluster_pred']=hc.fit_predict(x)

# %%
plt.scatter(clusters['CA100'],clusters['FT100'],c=clusters['cluster_pred'],cmap='rainbow',marker='*')
plt.xlabel('Continuous Assessment')
plt.ylabel('Formative Test')
plt.show()
